# %%
git clone https://github.com/sophiasang13/sangcs372final.git
# Out:
#   Cell In[2], line 1
#     git clone https://github.com/sophiasang13/sangcs372final.git
#         ^
# SyntaxError: invalid syntax
